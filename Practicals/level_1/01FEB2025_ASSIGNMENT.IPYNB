# %%
import os

# %%
class Robot:
    def __init__(self, name , type):
        self.name = name 
        self.type = type 
        print(f"Robot of type {self.type} is created")

# %%
chitti = Robot("chitti", "Domestic")
# Out:
# Robot of type Domestic is created
